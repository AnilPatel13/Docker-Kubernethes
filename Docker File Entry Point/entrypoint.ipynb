# %%
# !docker run busybox

# %%
# !docker inspect busybox
# Out:
# [
#     {
#         "Id": "sha256:f9a104fddb33220ec80fc45a4e606c74aadf1ef7a3832eb0b05be9e90cd61f5f",
#         "RepoTags": [
#             "busybox:latest"
#         ],
#         "RepoDigests": [
#             "busybox@sha256:f9a104fddb33220ec80fc45a4e606c74aadf1ef7a3832eb0b05be9e90cd61f5f"
#         ],
#         "Parent": "",
#         "Comment": "",
#         "Created": "2024-09-26T21:31:42Z",
#         "DockerVersion": "",
#         "Author": "",
#         "Architecture": "amd64",
#         "Os": "linux",
#         "Size": 2156518,
#         "GraphDriver": {
#             "Data": null,
#             "Name": "overlayfs"
#         },
#         "RootFS": {
#             "Type": "layers",
#             "Layers": [
#                 "sha256:65014c70e84b6817fac42bb201ec5c1ea460a8da246cac0e481f5c9a9491eac0"
#             ]
#         },
#         "Metadata": {
#             "LastTagTime": "2025-08-10T18:09:57.955073923Z"
#         },
#         "Descriptor": {
# ...

# %%
# !docker run -it busybox
# Out:
# the input device is not a TTY.  If you are using mintty, try prefixing the command with 'winpty'

# %%
# !docker build -t hostname .
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 78B done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/busybox:latest
# #2 DONE 0.0s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [1/1] FROM docker.io/library/busybox:latest@sha256:f9a104fddb33220ec80fc45a4e606c74aadf1ef7a3832eb0b05be9e90cd61f5f
# #4 resolve docker.io/library/busybox:latest@sha256:f9a104fddb33220ec80fc45a4e606c74aadf1ef7a3832eb0b05be9e90cd61f5f 0.0s done
# #4 CACHED
#
# #5 exporting to image
# #5 exporting layers done
# #5 exporting manifest sha256:a4337ee4e597a77d86c90f1d554ca71f182313b2249a1cf2dfd9afc13b2acab5 0.0s done
# #5 exporting config sha256:5560a57f1b2a937abeaf04d9c584033521f8bf7c3223ea70c47c86051e700c53 0.0s done
# #5 exporting attestation manifest sha256:09b74d805c2a08023a9ffeb213b51cf826d2c38307fb3e866a63df6b6791c5f9
# ...

# %%
# !docker image ls
# Out:
# REPOSITORY                 TAG             IMAGE ID       CREATED         SIZE
# flask-bind-demo            latest          8d45516740d9   2 hours ago     219MB
# anil1318/testing-node      latest          6c22e5416c99   5 hours ago     102MB
# testnode                   latest          6c22e5416c99   5 hours ago     102MB
# nginx-with-html            latest          6147e8cdc270   5 hours ago     279MB
# anil1318/nginx-with-html   latest          6147e8cdc270   5 hours ago     279MB
# customnginx                latest          5c04ecb61e81   6 hours ago     279MB
# mongo                      latest          a6bda40d00e5   2 weeks ago     1.22GB
# httpd                      latest          fbc12199ccad   2 weeks ago     221MB
# mysql                      latest          a776e89aad2d   2 weeks ago     1.26GB
# curlimages/curl            latest          4026b29997dc   3 weeks ago     33.5MB
# bretfisher/jekyll-serve    latest          fb55300b4f16   3 weeks ago     732MB
# ...

# %%
# !docker run hostname
# Out:
# Mon Aug 11 01:32:17 UTC 2025

# %%
# !docker run --help
# Out:
# Usage:  docker run [OPTIONS] IMAGE [COMMAND] [ARG...]
#
# Create and run a new container from an image
#
# Aliases:
#   docker container run, docker run
#
# Options:
#       --add-host list                    Add a custom host-to-IP mapping
#                                          (host:ip)
#       --annotation map                   Add an annotation to the
#                                          container (passed through to the
#                                          OCI runtime) (default map[])
#   -a, --attach list                      Attach to STDIN, STDOUT or STDERR
#       --blkio-weight uint16              Block IO (relative weight),
#                                          between 10 and 1000, or 0 to
#                                          disable (default 0)
#       --blkio-weight-device list         Block IO weight (relative device
#                                          weight) (default [])
# ...

# %%
# !docker container run hostname date
# Out:
# Mon Aug 11 01:33:32 UTC 2025

# %%
# !docker build -t entryhostname .
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 85B done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/busybox:latest
# #2 DONE 0.1s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [1/1] FROM docker.io/library/busybox:latest@sha256:f9a104fddb33220ec80fc45a4e606c74aadf1ef7a3832eb0b05be9e90cd61f5f
# #4 resolve docker.io/library/busybox:latest@sha256:f9a104fddb33220ec80fc45a4e606c74aadf1ef7a3832eb0b05be9e90cd61f5f 0.0s done
# #4 CACHED
#
# #5 exporting to image
# #5 exporting layers done
# #5 exporting manifest sha256:e076a1ea0c6f7d8ee834113992511d01c29b51672728d027a2861ca9d4d63993 0.0s done
# #5 exporting config sha256:29ae73b166056a13659e9a35aff32e4ed5be70a1a7b4ef66001e61e5b12a7488 0.0s done
# #5 exporting attestation manifest sha256:121c532959edef29deecc24b4b1161c68cd9210c9253da66fa5fe0bdf5b34a06 0.1s done
# ...

# %%
# !docker run entryhostname
# Out:
# 535ed873f185

# %%
# !docker run entryhostname date
# Out:
# hostname: sethostname: Operation not permitted

# %%
# !docker inspect entryhostname
# Out:
# [
#     {
#         "Id": "sha256:86982af660b671f8e7cc2609bcc732a898134baad25f31c63e9e063948aaecd8",
#         "RepoTags": [
#             "entryhostname:latest"
#         ],
#         "RepoDigests": [
#             "entryhostname@sha256:86982af660b671f8e7cc2609bcc732a898134baad25f31c63e9e063948aaecd8"
#         ],
#         "Parent": "",
#         "Comment": "buildkit.dockerfile.v0",
#         "Created": "2024-09-26T21:31:42Z",
#         "DockerVersion": "",
#         "Author": "",
#         "Architecture": "amd64",
#         "Os": "linux",
#         "Size": 2147107,
#         "GraphDriver": {
#             "Data": null,
#             "Name": "overlayfs"
#         },
#         "RootFS": {
#             "Type": "layers",
#             "Layers": [
#                 "sha256:65014c70e84b6817fac42bb201ec5c1ea460a8da246cac0e481f5c9a9491eac0"
#             ]
#         },
#         "Metadata": {
#             "LastTagTime": "2025-08-11T01:34:31.062675588Z"
#         },
# ...

# %%
# !docker run --help
# Out:
# Usage:  docker run [OPTIONS] IMAGE [COMMAND] [ARG...]
#
# Create and run a new container from an image
#
# Aliases:
#   docker container run, docker run
#
# Options:
#       --add-host list                    Add a custom host-to-IP mapping
#                                          (host:ip)
#       --annotation map                   Add an annotation to the
#                                          container (passed through to the
#                                          OCI runtime) (default map[])
#   -a, --attach list                      Attach to STDIN, STDOUT or STDERR
#       --blkio-weight uint16              Block IO (relative weight),
#                                          between 10 and 1000, or 0 to
#                                          disable (default 0)
#       --blkio-weight-device list         Block IO weight (relative device
#                                          weight) (default [])
# ...

# %%
# !docker run --entrypoint date entryhostname
# Out:
# Mon Aug 11 01:37:06 UTC 2025
