# %%
# !docker image build -t customnginx .
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 6.70kB done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/debian:bookworm-slim
# #2 DONE 0.2s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [1/2] FROM docker.io/library/debian:bookworm-slim@sha256:2424c1850714a4d94666ec928e24d86de958646737b1d113f5b2207be44d37d8
# #4 resolve docker.io/library/debian:bookworm-slim@sha256:2424c1850714a4d94666ec928e24d86de958646737b1d113f5b2207be44d37d8 0.0s done
# #4 DONE 0.0s
#
# ...

# %%
# !docker image ls
# Out:
# REPOSITORY              TAG             IMAGE ID       CREATED              SIZE
# customnginx             latest          59037ed0c936   About a minute ago   279MB
# mongo                   latest          a6bda40d00e5   2 weeks ago          1.22GB
# httpd                   latest          fbc12199ccad   2 weeks ago          221MB
# mysql                   latest          a776e89aad2d   2 weeks ago          1.26GB
# curlimages/curl         latest          4026b29997dc   3 weeks ago          33.5MB
# alpine                  latest          4bcff63911fc   3 weeks ago          12.8MB
# nginx                   latest          84ec966e61a8   3 weeks ago          279MB
# nginx                   mainline        84ec966e61a8   3 weeks ago          279MB
# anil1318/nginx          latest          84ec966e61a8   3 weeks ago          279MB
# anil1318/testing        latest          84ec966e61a8   3 weeks ago          279MB
# ...

# %%
# !docker image build -t customnginx .
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 6.70kB done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/debian:bookworm-slim
# #2 DONE 0.2s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [1/2] FROM docker.io/library/debian:bookworm-slim@sha256:2424c1850714a4d94666ec928e24d86de958646737b1d113f5b2207be44d37d8
# #4 resolve docker.io/library/debian:bookworm-slim@sha256:2424c1850714a4d94666ec928e24d86de958646737b1d113f5b2207be44d37d8 0.0s done
# #4 DONE 0.0s
#
# ...

# %%
# !docker image build -t nginx-with-html ./custom_Image/.
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 459B done
# #1 DONE 0.1s
#
# #2 [internal] load metadata for docker.io/library/nginx:latest
# #2 DONE 0.1s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.1s
#
# #4 [1/3] FROM docker.io/library/nginx:latest@sha256:84ec966e61a8c7846f509da7eb081c55c1d56817448728924a87ab32f12a72fb
# #4 resolve docker.io/library/nginx:latest@sha256:84ec966e61a8c7846f509da7eb081c55c1d56817448728924a87ab32f12a72fb 0.1s done
# #4 ...
#
# #5 [internal] load build context
# #5 transferring context: 297B done
# #5 DONE 0.1s
#
# #4 [1/3] FROM docker.io/library/nginx:latest@sha256:84ec966e61a8c7846f509da7eb081c55c1d56817448728924a87ab32f12a72fb
# #4 DONE 0.4s
#
# #6 [2/3] WORKDIR /usr/share/nginx/html
# #6 DONE 0.1s
#
# #7 [3/3] COPY index.html index.html
# #7 DONE 0.1s
#
# #8 exporting to image
# #8 exporting layers
# ...

# %%
# !docker container run -p 81:80 --rm nginx-with-html
# Out:
# ^C

# %%
# !docker image ls
# Out:
# REPOSITORY              TAG             IMAGE ID       CREATED              SIZE
# nginx-with-html         latest          6147e8cdc270   About a minute ago   279MB
# customnginx             latest          5c04ecb61e81   11 minutes ago       279MB
# mongo                   latest          a6bda40d00e5   2 weeks ago          1.22GB
# httpd                   latest          fbc12199ccad   2 weeks ago          221MB
# mysql                   latest          a776e89aad2d   2 weeks ago          1.26GB
# curlimages/curl         latest          4026b29997dc   3 weeks ago          33.5MB
# alpine                  latest          4bcff63911fc   3 weeks ago          12.8MB
# anil1318/nginx          latest          84ec966e61a8   3 weeks ago          279MB
# anil1318/testing        latest          84ec966e61a8   3 weeks ago          279MB
# nginx                   latest          84ec966e61a8   3 weeks ago          279MB
# ...

# %%
# !docker image tag nginx-with-html:latest anil1318/nginx-with-html:latest

# %%
# !docker image ls
# Out:
# REPOSITORY                 TAG             IMAGE ID       CREATED          SIZE
# anil1318/nginx-with-html   latest          6147e8cdc270   2 minutes ago    279MB
# nginx-with-html            latest          6147e8cdc270   2 minutes ago    279MB
# customnginx                latest          5c04ecb61e81   12 minutes ago   279MB
# mongo                      latest          a6bda40d00e5   2 weeks ago      1.22GB
# httpd                      latest          fbc12199ccad   2 weeks ago      221MB
# mysql                      latest          a776e89aad2d   2 weeks ago      1.26GB
# curlimages/curl            latest          4026b29997dc   3 weeks ago      33.5MB
# alpine                     latest          4bcff63911fc   3 weeks ago      12.8MB
# anil1318/nginx             latest          84ec966e61a8   3 weeks ago      279MB
# anil1318/testing           latest          84ec966e61a8   3 weeks ago      279MB
# nginx                      latest          84ec966e61a8   3 weeks ago      279MB
# ...

# %%
# !docker image push anil1318/nginx-with-html
# Out:
# Using default tag: latest
# The push refers to repository [docker.io/anil1318/nginx-with-html]
# 2a81ab1498f9: Waiting
# 96e47e70491e: Waiting
# 1d9f51194194: Waiting
# f30ffbee4c54: Waiting
# e28b6dd4be49: Waiting
# 2ef442a3816e: Waiting
# 4b1e45a9989f: Waiting
# 59e22667830b: Waiting
# 140da4f89dcb: Waiting
# 4f4fb700ef54: Waiting
# 59e22667830b: Waiting
# 140da4f89dcb: Waiting
# 4f4fb700ef54: Waiting
# 2a81ab1498f9: Waiting
# 96e47e70491e: Waiting
# 1d9f51194194: Waiting
# f30ffbee4c54: Waiting
# e28b6dd4be49: Waiting
# 2ef442a3816e: Waiting
# 4b1e45a9989f: Waiting
# e28b6dd4be49: Waiting
# 2ef442a3816e: Waiting
# 4b1e45a9989f: Waiting
# 59e22667830b: Waiting
# 140da4f89dcb: Waiting
# 4f4fb700ef54: Waiting
# 2a81ab1498f9: Waiting
# 96e47e70491e: Waiting
# 1d9f51194194: Waiting
# f30ffbee4c54: Waiting
# 2a81ab1498f9: Waiting
# 96e47e70491e: Waiting
# 1d9f51194194: Waiting
# f30ffbee4c54: Waiting
# e28b6dd4be49: Waiting
# 2ef442a3816e: Waiting
# 4b1e45a9989f: Waiting
# ...

# %%
# !docker build -t testnode ./docker-file-assignment-1/.
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 257B done
# #1 DONE 0.1s
#
# #2 [internal] load metadata for docker.io/library/node:6-alpine
# #2 ...
#
# #3 [auth] library/node:pull token for registry-1.docker.io
# #3 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/node:6-alpine
# #2 DONE 0.9s
#
# #4 [internal] load .dockerignore
# #4 transferring context: 444B done
# #4 DONE 0.1s
#
# #5 [internal] load build context
# #5 transferring context: 426.56kB 0.0s done
# #5 DONE 0.1s
#
# #6 [1/6] FROM docker.io/library/node:6-alpine@sha256:17258206fc9256633c7100006b1cfdf25b129b6a40b8e5d37c175026482c84e3
# #6 resolve docker.io/library/node:6-alpine@sha256:17258206fc9256633c7100006b1cfdf25b129b6a40b8e5d37c175026482c84e3 0.1s done
# #6 DONE 0.3s
#
# #6 [1/6] FROM docker.io/library/node:6-alpine@sha256:17258206fc9256633c7100006b1cfdf25b129b6a40b8e5d37c175026482c84e3
# ...

# %%
# !docker image ls
# Out:
# REPOSITORY                 TAG             IMAGE ID       CREATED          SIZE
# testnode                   latest          6c22e5416c99   15 seconds ago   102MB
# anil1318/nginx-with-html   latest          6147e8cdc270   14 minutes ago   279MB
# nginx-with-html            latest          6147e8cdc270   14 minutes ago   279MB
# customnginx                latest          5c04ecb61e81   24 minutes ago   279MB
# mongo                      latest          a6bda40d00e5   2 weeks ago      1.22GB
# httpd                      latest          fbc12199ccad   2 weeks ago      221MB
# mysql                      latest          a776e89aad2d   2 weeks ago      1.26GB
# curlimages/curl            latest          4026b29997dc   3 weeks ago      33.5MB
# alpine                     latest          4bcff63911fc   3 weeks ago      12.8MB
# anil1318/nginx             latest          84ec966e61a8   3 weeks ago      279MB
# anil1318/testing           latest          84ec966e61a8   3 weeks ago      279MB
# ...

# %%
# !docker container run --rm -p 82:3000 testnode
# Out:
# ^C

# %%
# !docker tag testnode anil1318/testing-node:latest

# %%
# !docker push anil1318/testing-node:latest
# Out:
# The push refers to repository [docker.io/anil1318/testing-node]
# e11ea2e382f9: Waiting
# 22d0ed0f8506: Waiting
# 50b250fcada1: Waiting
# e9fa13fdf0f5: Waiting
# 2220642e2390: Waiting
# ccc877228d8f: Waiting
# b745d47aa324: Waiting
# 2f0d78609145: Waiting
# bdf0201b3a05: Waiting
# e11ea2e382f9: Waiting
# 22d0ed0f8506: Waiting
# 50b250fcada1: Waiting
# e9fa13fdf0f5: Waiting
# 2220642e2390: Waiting
# ccc877228d8f: Waiting
# b745d47aa324: Waiting
# 2f0d78609145: Waiting
# bdf0201b3a05: Waiting
# e11ea2e382f9: Waiting
# 22d0ed0f8506: Waiting
# 50b250fcada1: Waiting
# e9fa13fdf0f5: Waiting
# 2220642e2390: Waiting
# ccc877228d8f: Waiting
# b745d47aa324: Waiting
# 2f0d78609145: Waiting
# bdf0201b3a05: Waiting
# b745d47aa324: Waiting
# 2f0d78609145: Waiting
# bdf0201b3a05: Waiting
# e11ea2e382f9: Waiting
# 22d0ed0f8506: Waiting
# 50b250fcada1: Waiting
# e9fa13fdf0f5: Waiting
# 2220642e2390: Waiting
# ccc877228d8f: Waiting
# 2220642e2390: Waiting
# ccc877228d8f: Waiting
# ...
