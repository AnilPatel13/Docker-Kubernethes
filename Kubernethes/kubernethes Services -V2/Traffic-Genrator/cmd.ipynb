# %%
# !traffic-gen.bat http://localhost:8080/api 0.5
# Out:
# ^C
# Sending request to http://localhost:8080/api every 0.5 seconds..
# Sat 08/30/2025 15:24:16.81
# Sat 08/30/2025 15:24:19.08
# ERROR: Invalid value for timeout (/T) specified. Valid range is -1 to 99999.
# ERROR: Invalid value for timeout (/T) specified. Valid range is -1 to 99999.

# %%
# !docker build -t anil1318/traffic-gen:1.0.0 .
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 208B done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/alpine:3.20
# #2 DONE 0.1s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [1/5] FROM docker.io/library/alpine:3.20@sha256:b3119ef930faabb6b7b976780c0c7a9c1aa24d0c75e9179ac10e6bc9ac080d0d
# #4 resolve docker.io/library/alpine:3.20@sha256:b3119ef930faabb6b7b976780c0c7a9c1aa24d0c75e9179ac10e6bc9ac080d0d 0.0s done
# #4 DONE 0.0s
#
# #5 [internal] load build context
# #5 transferring context: 421B done
# #5 DONE 0.0s
#
# #6 [2/5] WORKDIR /app
# #6 CACHED
#
# #7 [3/5] RUN apk add --no-cache curl
# #7 CACHED
#
# #8 [4/5] COPY traffic-gen.sh traffic-gen.sh
# #8 DONE 0.1s
#
# #9 [5/5] RUN chmod +x traffic-gen.sh
# #9 DONE 0.3s
#
# #10 exporting to image
# #10 exporting layers
# #10 exporting layers 0.3s done
# ...

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED          STATUS          PORTS                                 NAMES
# 20b933c7dbf1   anil1318/color-api:1.1.0   "docker-entrypoint.s…"   29 minutes ago   Up 29 minutes   0.0.0.0:80->80/tcp, [::]:80->80/tcp   crazy_chaum

# %%
# !docker run anil1318/traffic-gen:1.0.0 "localhost:8080/api" 0.5
# Out:
# ^C
# Sending request to localhost:8080/api every 0.5 seconds..
# 2025-08-30 19:27:50
# 2025-08-30 19:27:51
# 2025-08-30 19:27:51
# 2025-08-30 19:27:52
# 2025-08-30 19:27:52
# 2025-08-30 19:27:53
# 2025-08-30 19:27:53
# 2025-08-30 19:27:54
# 2025-08-30 19:27:54
# 2025-08-30 19:27:55
# 2025-08-30 19:27:55
# 2025-08-30 19:27:56
# 2025-08-30 19:27:56
# 2025-08-30 19:27:57
# 2025-08-30 19:27:57
# 2025-08-30 19:27:58
# 2025-08-30 19:27:58
# 2025-08-30 19:27:59
# 2025-08-30 19:27:59
# 2025-08-30 19:28:00
# 2025-08-30 19:28:00
# 2025-08-30 19:28:01
# 2025-08-30 19:28:01
# 2025-08-30 19:28:02
# 2025-08-30 19:28:02
# 2025-08-30 19:28:03
# 2025-08-30 19:28:03
# 2025-08-30 19:28:04
# 2025-08-30 19:28:04
# 2025-08-30 19:28:05
# 2025-08-30 19:28:05
# 2025-08-30 19:28:06
# 2025-08-30 19:28:06
# 2025-08-30 19:28:07
# 2025-08-30 19:28:07
# 2025-08-30 19:28:08
# 2025-08-30 19:28:08
# 2025-08-30 19:28:09
# 2025-08-30 19:28:09
# 2025-08-30 19:28:10
# 2025-08-30 19:28:10
# 2025-08-30 19:28:11
# ...

# %%
# !docker push anil1318/traffic-gen:1.0.0
# Out:
# The push refers to repository [docker.io/anil1318/traffic-gen]
# feb74fc46c14: Waiting
# 4f4fb700ef54: Waiting
# 01d036902a3c: Waiting
# 1d3c14ea75cf: Waiting
# 22524ecefd1e: Waiting
# 6b844ae7c728: Waiting
# feb74fc46c14: Waiting
# 4f4fb700ef54: Waiting
# 01d036902a3c: Waiting
# 1d3c14ea75cf: Waiting
# 22524ecefd1e: Waiting
# 6b844ae7c728: Waiting
# 6b844ae7c728: Waiting
# feb74fc46c14: Waiting
# 4f4fb700ef54: Waiting
# 01d036902a3c: Waiting
# 1d3c14ea75cf: Waiting
# 22524ecefd1e: Waiting
# 01d036902a3c: Mounted from library/alpine
# 1d3c14ea75cf: Waiting
# 22524ecefd1e: Waiting
# 6b844ae7c728: Waiting
# 4f4fb700ef54: Waiting
# 4f4fb700ef54: Mounted from anil1318/welcome-app
# feb74fc46c14: Pushed
# 1d3c14ea75cf: Pushed
# 6b844ae7c728: Pushed
# 22524ecefd1e: Pushed
# 1.0.0: digest: sha256:cb4fcb237d39ec4d6aebdccf1fd265cd5a775f1e649766370d1a473b3d2a3efb size: 856
