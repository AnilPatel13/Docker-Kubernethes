# %%
# !kubectl apply -f SERVICES/external-name.yaml
# Out:
# service/my-external-service configured

# %%
# !kubectl get svc
# Out:
# NAME                  TYPE           CLUSTER-IP       EXTERNAL-IP      PORT(S)        AGE
# color-api-clusterip   ClusterIP      10.101.107.120   <none>           80/TCP         28m
# color-api-nodeport    NodePort       10.106.218.94    <none>           80:30007/TCP   23m
# kubernetes            ClusterIP      10.96.0.1        <none>           443/TCP        44h
# my-external-service   ExternalName   <none>           www.google.com   <none>         8m12s

# %%
# !kubectl apply -f SERVICES/extername-pod-test.yaml
# Out:
# pod/traffic-generator unchanged

# %%
# !kubectl logs traffic-generator
# Out:
# Sending request to my-external-service every 0.5 seconds..
# 2025-08-30 20:34:51 <!DOCTYPE html>
# <html lang=en>
#   <meta charset=utf-8>
#   <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">
#   <title>Error 404 (Not Found)!!1</title>
#   <style>
# ...

# %%
# !kubectl run curl-test --restart=Never --rm -i --image=curlimages/curl:8.9.0 -- curl -sI http://my-external-service
# Out:
# HTTP/1.1 404 Not Found
# Transfer-Encoding: chunked
# Date: Sat, 30 Aug 2025 20:43:46 GMT
# Content-Type: text/html; charset=UTF-8
#
# pod "curl-test" deleted

# %%
# !kubectl run curl-test --restart=Never --rm -i --image=curlimages/curl:8.9.0 -- curl -sI -H "Host: www.google.com" http://my-external-service
# Out:
# HTTP/1.1 200 OK
# Content-Type: text/html; charset=ISO-8859-1
# Content-Security-Policy-Report-Only: object-src 'none';base-uri 'self';script-src 'nonce-DCKYUWMdczgDW4td5iZn-A' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other-hp
# P3P: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# Date: Sat, 30 Aug 2025 20:43:55 GMT
# Server: gws
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Transfer-Encoding: chunked
# Expires: Sat, 30 Aug 2025 20:43:55 GMT
# Cache-Control: private
# Set-Cookie: AEC=AVh_V2ixxi822DkJVy0bZxvhPX0IVPmfSA9tXFwlsLbQ4ObE_VE51k9Q; expires=Thu, 26-Feb-2026 20:43:55 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax
# ...

# %%
# !kubectl delete -f SERVICES/.
# Out:
# service "color-api-clusterip" deleted
# deployment.apps "color-api-deployment" deleted
# service "color-api-nodeport" deleted
# service "my-external-service" deleted
# pod "traffic-generator" deleted
# pod "traffic-generator" deleted
